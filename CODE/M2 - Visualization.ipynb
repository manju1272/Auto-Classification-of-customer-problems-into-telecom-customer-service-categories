# %% [markdown]
# # Module - 2

# %% [markdown]
# # Visualization

# %%
import pandas as p
import numpy as n
import seaborn as s
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
data=p.read_csv('churn.csv')

# %%
data
# Out:
#      Customer ID  Gender  Age  Zip Code   Latitude   Longitude  \
# 0     0002-ORFBO  Female   37     93225  34.827662 -118.999073
# 1     0003-MKNFE    Male   46     91206  34.162515 -118.203869
# 2     0004-TLHLJ    Male   50     92627  33.645672 -117.922613
# 3     0011-IGKFF    Male   78     94553  38.014457 -122.115432
# 4     0013-EXCHZ  Female   75     93010  34.227846 -119.079903
# ...          ...     ...  ...       ...        ...         ...
# 7038  9987-LUTYD  Female   20     91941  32.759327 -116.997260
# 7039  9992-RRAMN    Male   40     95367  37.734971 -120.954271
# 7040  9992-UJOEL    Male   22     95432  39.108252 -123.645121
# 7041  9993-LHIEB    Male   21     92075  33.001813 -117.263628
# 7042  9995-HOTOH    Male   36     96125  39.600599 -120.636358
#
#       Tenure in Months    Offer Internet Type  Avg Monthly GB Download  \
# 0                    9      NaN         Cable                     16.0
# 1                    9      NaN         Cable                     10.0
# 2                    4  Offer E   Fiber Optic                     30.0
# 3                   13  Offer D   Fiber Optic                      4.0
# 4                    3      NaN   Fiber Optic                     11.0
# ...                ...      ...           ...                      ...
# 7038                13  Offer D           DSL                     59.0
# 7039                22  Offer D   Fiber Optic                     17.0
# 7040                 2  Offer E           DSL                     51.0
# 7041                67  Offer A         Cable                     58.0
# 7042                63      NaN         Cable                      5.0
#
#      Unlimited Data        Contract   Payment Method  Monthly Charge  \
# 0               Yes        One Year      Credit Card           65.60
# 1                No  Month-to-Month      Credit Card           -4.00
# 2               Yes  Month-to-Month  Bank Withdrawal           73.90
# 3               Yes  Month-to-Month  Bank Withdrawal           98.00
# 4               Yes  Month-to-Month      Credit Card           83.90
# ...             ...             ...              ...             ...
# 7038            Yes        One Year      Credit Card           55.15
# 7039            Yes  Month-to-Month  Bank Withdrawal           85.10
# 7040            Yes  Month-to-Month      Credit Card           50.30
# 7041            Yes        Two Year      Credit Card           67.85
# 7042            Yes        Two Year  Bank Withdrawal           59.00
#
#       Total Charges  Total Extra Data Charges  Total Revenue Customer Status
# 0            593.30                         0         974.81          Stayed
# 1            542.40                        10         610.28          Stayed
# 2            280.85                         0         415.45         Churned
# 3           1237.85                         0        1599.51         Churned
# 4            267.40                         0         289.54         Churned
# ...             ...                       ...            ...             ...
# 7038         742.90                         0        1349.74          Stayed
# 7039        1873.70                         0        2230.10         Churned
# 7040          92.75                         0         129.99          Joined
# 7041        4627.65                         0        4769.69          Stayed
# 7042        3707.60                         0        3707.60          Stayed
#
# [7043 rows x 18 columns]

# %%
df=data.dropna()

# %%
df = df.rename({'Customer ID': 'Customer_ID', 'Number of Dependents': 'Number_of_Dependents',
                'Zip Code': 'Zip_Code', 'Number of Referrals': 'Number_of_Referrals',
                'Tenure in Months': 'Tenure_in_Months', 'Phone Service': 'Phone_Service',
                'Avg Monthly Long Distance Charges': 'Avg_Monthly_Long_Distance_Charges', 'Multiple Lines': 'Multiple_Lines',
                'Internet Service': 'Internet_Service', 'Internet Type': 'Internet_Type',
                'Avg Monthly GB Download': 'Avg_Monthly_GB_Download', 'Online Security': 'Online_Security',
                'Online Backup': 'Online_Backup', 'Device Protection Plan': 'Device_Protection_Plan',
                'Premium Tech Support': 'Premium_Tech_Support', 'Streaming TV': 'Streaming_TV',
                'Streaming Movies': 'Streaming_Movies', 'Streaming Music': 'Streaming_Music',
                'Unlimited Data': 'Unlimited_Data', 'Paperless Billing': 'Paperless_Billin',
                'Payment Method': 'Payment_Method', 'Monthly Charge': 'Monthly_Charge',
                'Total Charges': 'Total_Charges', 'Total Refunds': 'Total_Refunds',
                'Total Extra Data Charges': 'Total_Extra_Data_Charges', 'Total Long Distance Charges': 'Total_Long_Distance_Charges',
                'Total Revenue': 'Total_Revenue', 'Customer Status': 'Customer_Status'}, axis=1)

# %%
#Histogram
df['Total_Charges'].hist(figsize=(8,4), color='m', alpha=1)
plt.xlabel('Total Charges')
plt.ylabel('Total Count')
plt.title('Total Charges')
# Out:
# Text(0.5, 1.0, 'Total Charges')

# %%
plt.figure(figsize=(8,4))
plt.hist(df['Avg_Monthly_GB_Download'])
plt.title("Average Monthly Downloaded")
plt.xlabel("Downloaded GB")
plt.ylabel("Total Users in our dataset")
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.scatter(df["Longitude"],df["Latitude"],color="red")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2493 entries, 2 to 7041
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Customer_ID               2493 non-null   object
#  1   Gender                    2493 non-null   object
#  2   Age                       2493 non-null   int64
#  3   Zip_Code                  2493 non-null   int64
#  4   Latitude                  2493 non-null   float64
#  5   Longitude                 2493 non-null   float64
#  6   Tenure_in_Months          2493 non-null   int64
#  7   Offer                     2493 non-null   object
#  8   Internet_Type             2493 non-null   object
#  9   Avg_Monthly_GB_Download   2493 non-null   float64
#  10  Unlimited_Data            2493 non-null   object
#  11  Contract                  2493 non-null   object
#  12  Payment_Method            2493 non-null   object
#  13  Monthly_Charge            2493 non-null   float64
#  14  Total_Charges             2493 non-null   float64
#  15  Total_Extra_Data_Charges  2493 non-null   int64
#  16  Total_Revenue             2493 non-null   float64
#  17  Customer_Status           2493 non-null   object
# dtypes: float64(6), int64(4), object(8)
# memory usage: 370.1+ KB

# %%
df.columns
# Out:
# Index(['Customer_ID', 'Gender', 'Age', 'Zip_Code', 'Latitude', 'Longitude',
#        'Tenure_in_Months', 'Offer', 'Internet_Type', 'Avg_Monthly_GB_Download',
#        'Unlimited_Data', 'Contract', 'Payment_Method', 'Monthly_Charge',
#        'Total_Charges', 'Total_Extra_Data_Charges', 'Total_Revenue',
#        'Customer_Status'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

var = ['Customer_ID','Gender','Internet_Type','Offer','Unlimited_Data','Contract','Payment_Method','Customer_Status']

for i in var:
    df[i] = le.fit_transform(df[i]).astype(int)

# %%
df["Tenure_in_Months"]
# Out:
# 2        4
# 3       13
# 5        9
# 6       71
# 7       63
#         ..
# 7036     1
# 7038    13
# 7039    22
# 7040     2
# 7041    67
# Name: Tenure_in_Months, Length: 2493, dtype: int64

# %%
#Density Subplot
plt.figure(figsize= (12,10))
plt.subplot(5,2,1)
df["Age"].plot(kind='density')
plt.subplot(5,2,2)
df["Zip_Code"].plot(kind='density')
plt.subplot(5,2,3)
df["Latitude"].plot(kind='density')
plt.subplot(5,2,4)
df["Longitude"].plot(kind='density')
plt.subplot(5,2,5)
df["Avg_Monthly_GB_Download"].plot(kind='density')
plt.subplot(5,2,6)
df["Monthly_Charge"].plot(kind='density')
plt.subplot(5,2,7)
df["Monthly_Charge"].plot(kind='density')
plt.subplot(5,2,8)
df["Total_Charges"].plot(kind='density')
plt.subplot(5,2,9)
df["Total_Extra_Data_Charges"].plot(kind='density')
plt.subplot(5,2,10)
df["Total_Revenue"].plot(kind='density')
plt.show()

# %%
def piechart(df, variable):
    dataframe_pie = df[variable].value_counts()
    ax = dataframe_pie.plot.pie(figsize=(9,9), autopct='%1.2f%%', fontsize = 10)
    ax.set_title(variable + ' \n', fontsize = 10)
    return n.round(dataframe_pie/df.shape[0]*100,2)

piechart(df, 'Contract')
# Out:
# Contract
# 0    54.55
# 2    23.47
# 1    21.98
# Name: count, dtype: float64

# %%
piechart(df, 'Payment_Method')
# Out:
# Payment_Method
# 0    61.69
# 1    33.05
# 2     5.25
# Name: count, dtype: float64

# %%
piechart(df, 'Customer_Status')
# Out:
# Customer_Status
# 2    64.98
# 0    30.37
# 1     4.65
# Name: count, dtype: float64

# %%
fig, ax = plt.subplots(figsize=(25,12))
s.heatmap(df.corr(),annot = True, fmt='0.2%',cmap = 'Spectral',ax=ax)
#YlGnBu, Reds, tab10, rocket, mako, flare, crest, magma, viridis, cubehelix, YlOrBr, vlag, icefire, Spectral, coolwarm, Blues
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 2
#       1 fig, ax = plt.subplots(figsize=(25,12))
# ----> 2 s.heatmap(df.corr(),annot = True, fmt='0.2%',cmap = 'Spectral',ax=ax)
#
# File ~\anaconda3\envs\project\Lib\site-packages\pandas\core\frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\anaconda3\envs\project\Lib\site-packages\pandas\core\frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839 if result.dtype is not dtype:
#    1840     result = np.array(result, dtype=dtype, copy=False)
#
# File ~\anaconda3\envs\project\Lib\site-packages\pandas\core\internals\managers.py:1732, in BlockManager.as_array(self, dtype, copy, na_value)
#    1730         arr.flags.writeable = False
#    1731 else:
# -> 1732     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1733     # The underlying data was copied within _interleave, so no need
#    1734     # to further copy if copy=True or setting na_value
#    1736 if na_value is not lib.no_default:
#
# File ~\anaconda3\envs\project\Lib\site-packages\pandas\core\internals\managers.py:1794, in BlockManager._interleave(self, dtype, na_value)
#    1792     else:
#    1793         arr = blk.get_values(dtype)
# -> 1794     result[rl.indexer] = arr
#    1795     itemmask[rl.indexer] = 1
#    1797 if not itemmask.all():
#
# ValueError: could not convert string to float: 'Offer E'

# %%
def Customer_Status(df, bygroup):
    dataframe_by_Group = p.crosstab(df[bygroup], columns=df["Customer_Status"], normalize = 'index')
    dataframe_by_Group = n.round((dataframe_by_Group * 100), decimals=2)
    ax = dataframe_by_Group.plot.bar(figsize=(15,7));
    vals = ax.get_yticks()
    ax.set_yticklabels(['{:3.0f}%'.format(x) for x in vals]);
    ax.set_xticklabels(dataframe_by_Group.index,rotation = 0, fontsize = 15);
    ax.set_title('Customer Status (%) (by ' + dataframe_by_Group.index.name + ')\n', fontsize = 15)
    ax.set_xlabel(dataframe_by_Group.index.name, fontsize = 12)
    ax.set_ylabel('(%)', fontsize = 12)
    ax.legend(loc = 'upper left',bbox_to_anchor=(1.0,1.0), fontsize= 12)
    rects = ax.patches

    # Add Data Labels

    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2, 
                height + 2, 
                str(height)+'%', 
                ha='center', 
                va='bottom',
                fontsize = 12)
    return dataframe_by_Group

# %%
Customer_Status(df, 'Gender')
# Out:
# Customer_Status      0     1      2
# Gender
# 0                29.85  4.19  65.95
# 1                30.85  5.09  64.06

# %%
Customer_Status(df, 'Offer')
# Out:
# Customer_Status      0      1      2
# Offer
# Offer A           8.18   0.00  91.82
# Offer B          14.65   0.00  85.35
# Offer C          27.84   0.00  72.16
# Offer D          34.55   0.00  65.45
# Offer E          60.28  18.35  21.36

# %%
Customer_Status(df, 'Contract')
# Out:
# Customer_Status      0     1      2
# Contract
# 0                49.04  7.28  43.68
# 1                12.77  1.09  86.13
# 2                 3.42  1.88  94.70
